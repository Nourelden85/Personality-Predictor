# %%
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix

# %%
x_train = pd.read_csv("../data/processed/x_train.csv")
x_test = pd.read_csv("../data/processed/x_test.csv")

y_train = pd.read_csv("../data/processed/y_train.csv")
y_test = pd.read_csv("../data/processed/y_test.csv")

# %% [markdown]
# ## **Model Training**

# %% [markdown]
# ### Logistic Regression with Grid Search

# %%
log_reg = LogisticRegression(max_iter = 1000 , random_state=42)

param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [0.01, 0.1, 1, 10, 50, 100],
    'class_weight': [None, 'balanced']
}


grid_search = GridSearchCV(
    estimator=log_reg,
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)

# %%
models = {}
for trait in y_train.columns:
    grid_search.fit(x_train, y_train[trait])
    best_model = grid_search.best_estimator_
    models[trait] = best_model


for trait, model in models.items():

    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)
   
    y_pred = model.predict(x_test)
    print(f"Classification Report for {trait}:\n")
    print(classification_report(y_test[trait], y_pred))
    print(f"Confusion Matrix for {trait}:\n")
    print(confusion_matrix(y_test[trait], y_pred))
    print("Train Accuracy:", accuracy_score(y_train[trait], y_pred_train))
    print("Test Accuracy:", accuracy_score(y_test[trait], y_pred_test))
    print('\n')
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1147, in fit
#     solver = _check_solver(self.solver, penalty, self.dual)
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py", line 65, in _check_solver
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [       nan 0.83872593        nan 0.83874676        nan 0.83864259
#         nan 0.83872593        nan 0.83868426        nan 0.83868426
#         nan 0.83868426        nan 0.83868426        nan 0.83868426
#         nan 0.83868426        nan 0.83868426        nan 0.83868426]
#   warnings.warn(
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1147, in fit
#     solver = _check_solver(self.solver, penalty, self.dual)
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py", line 65, in _check_solver
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [       nan 0.76205757        nan 0.76207841        nan 0.76201591
#         nan 0.76203674        nan 0.76203674        nan 0.76201591
#         nan 0.76205758        nan 0.76199507        nan 0.76205758
#         nan 0.76199507        nan 0.76205758        nan 0.76199507]
#   warnings.warn(
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1147, in fit
#     solver = _check_solver(self.solver, penalty, self.dual)
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py", line 65, in _check_solver
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [       nan 0.79830827        nan 0.79822495        nan 0.79828743
#         nan 0.79820411        nan 0.7982041         nan 0.79816245
#         nan 0.7982041         nan 0.79816245        nan 0.7982041
#         nan 0.79816245        nan 0.7982041         nan 0.79816245]
#   warnings.warn(
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py:490: FitFailedWarning:
# 60 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_validation.py", line 833, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py", line 1336, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1147, in fit
#     solver = _check_solver(self.solver, penalty, self.dual)
#   File "c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py", line 65, in _check_solver
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Solver lbfgs supports only 'l2' or None penalties, got l1 penalty.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_search.py:1137: UserWarning: One or more of the test scores are non-finite: [       nan 0.77943295        nan 0.77949545        nan 0.77934961
#         nan 0.77920377        nan 0.77924544        nan 0.77914127
#         nan 0.77924544        nan 0.77916211        nan 0.77924544
#         nan 0.77916211        nan 0.77924544        nan 0.77916211]
#   warnings.warn(
# c:\Users\Nour\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# Classification Report for Is_Extrovert:
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84      5930
#            1       0.84      0.84      0.84      6070
#
#     accuracy                           0.84     12000
#    macro avg       0.84      0.84      0.84     12000
# weighted avg       0.84      0.84      0.84     12000
#
# Confusion Matrix for Is_Extrovert:
#
# [[4959  971]
#  [ 963 5107]]
# Train Accuracy: 0.8392883185066355
# Test Accuracy: 0.8388333333333333
#
#
# Classification Report for Is_Sensor:
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.78      0.77      5965
#            1       0.78      0.76      0.77      6035
#
#     accuracy                           0.77     12000
#    macro avg       0.77      0.77      0.77     12000
# weighted avg       0.77      0.77      0.77     12000
#
# Confusion Matrix for Is_Sensor:
#
# [[4641 1324]
#  [1429 4606]]
# Train Accuracy: 0.7633075689076856
# Test Accuracy: 0.7705833333333333
#
#
# Classification Report for Is_Thinker:
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      6094
#            1       0.79      0.79      0.79      5906
#
#     accuracy                           0.79     12000
#    macro avg       0.79      0.79      0.79     12000
# weighted avg       0.79      0.79      0.79     12000
#
# Confusion Matrix for Is_Thinker:
#
# [[4848 1246]
#  [1221 4685]]
# Train Accuracy: 0.7989958124127586
# Test Accuracy: 0.7944166666666667
#
#
# Classification Report for Is_Judger:
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77      6047
#            1       0.77      0.77      0.77      5953
#
#     accuracy                           0.77     12000
#    macro avg       0.77      0.77      0.77     12000
# weighted avg       0.77      0.77      0.77     12000
#
# Confusion Matrix for Is_Judger:
#
# [[4663 1384]
#  [1350 4603]]
# Train Accuracy: 0.7798912477343278
# Test Accuracy: 0.7721666666666667

# %% [markdown]
# ### Logistic Regression Insights:
#
# **For Is_Sensor target:**
#
# Best Parameters: {'C': 0.1, 'class_weight': 'balanced', 'penalty': 'l2'}
#
# Train Accuracy: 0.7624117169107689
# Test Accuracy: 0.7696666666666667
#
# ---
#
# **For Is_Extrovert target:**
#
# Best Parameters: {'C': 0.01, 'class_weight': 'balanced', 'penalty': 'l2'}
#
# Train Accuracy: 0.8397258276214088 /
# Test Accuracy: 0.8398333333333333
#
# ---
#
# **For Is_Thinker target:**
#
# Best Parameters: {'C': 0.1, 'class_weight': None, 'penalty': 'l2'}
#
# Train Accuracy: 0.7930581887122649 /
# Test Accuracy: 0.794
#
# ---
#
# **For Is_Judger target:**
#
# Best Parameters: {'C': 10, 'class_weight': None, 'penalty': 'l2'}
#
# Train Accuracy: 0.7798704139669577 /
# Test Accuracy: 0.77175
#
#
# The results shows no overfittng nor underfitting , but it not the best accuracy

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# ### Decision Tree with Grid Search

# %%
param_grid = {
    'max_depth': [3,5,7,10],
    'min_samples_split': [2,5,10],
    'min_samples_leaf': [1,2,5]
}

grid = GridSearchCV(DecisionTreeClassifier(random_state=42),
                    param_grid,
                    cv=5,
                    scoring='accuracy')

# %%
models = {}
for trait in y_train.columns:
    grid.fit(x_train, y_train[trait])
    best_dt = grid.best_estimator_
    models[trait] = best_dt


for trait, model in models.items():

    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)
   
    y_pred = model.predict(x_test)
    print(f"Classification Report for {trait}:\n")
    print(classification_report(y_test[trait], y_pred))
    print(f"Confusion Matrix for {trait}:\n")
    print(confusion_matrix(y_test[trait], y_pred))
    print("Train Accuracy:", accuracy_score(y_train[trait], y_pred_train))
    print("Test Accuracy:", accuracy_score(y_test[trait], y_pred_test))
    print('\n')
# Out:
# Classification Report for Is_Extrovert:
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84      5930
#            1       0.85      0.82      0.84      6070
#
#     accuracy                           0.84     12000
#    macro avg       0.84      0.84      0.84     12000
# weighted avg       0.84      0.84      0.84     12000
#
# Confusion Matrix for Is_Extrovert:
#
# [[5035  895]
#  [1074 4996]]
# Train Accuracy: 0.8897477030771475
# Test Accuracy: 0.8359166666666666
#
#
# Classification Report for Is_Sensor:
#
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82      5965
#            1       0.83      0.81      0.82      6035
#
#     accuracy                           0.82     12000
#    macro avg       0.82      0.82      0.82     12000
# weighted avg       0.82      0.82      0.82     12000
#
# Confusion Matrix for Is_Sensor:
#
# [[4960 1005]
#  [1138 4897]]
# Train Accuracy: 0.8699972916102419
# Test Accuracy: 0.8214166666666667
#
#
# Classification Report for Is_Thinker:
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      6094
#            1       0.83      0.82      0.82      5906
#
#     accuracy                           0.83     12000
#    macro avg       0.83      0.83      0.83     12000
# weighted avg       0.83      0.83      0.83     12000
#
# Confusion Matrix for Is_Thinker:
#
# [[5077 1017]
#  [1074 4832]]
# Train Accuracy: 0.8726431800662514
# Test Accuracy: 0.82575
#
#
# Classification Report for Is_Judger:
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83      6047
#            1       0.82      0.84      0.83      5953
#
#     accuracy                           0.83     12000
#    macro avg       0.83      0.83      0.83     12000
# weighted avg       0.83      0.83      0.83     12000
#
# Confusion Matrix for Is_Judger:
#
# [[4933 1114]
#  [ 954 4999]]
# Train Accuracy: 0.8732473593199859
# Test Accuracy: 0.8276666666666667

# %% [markdown]
# ### **Decision Tree Insights:**
#
# **For Is_Sensor target:**
#
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}
#
# Train Accuracy: 0.8721223358819975 /
# Test Accuracy: 0.8215833333333333
#
# ---
#
# **For Is_Extrovert target:**
#
# Best Parameters: {'C': 0.01, 'class_weight': 'balanced', 'penalty': 'l2'}
#
# Train Accuracy: 0.8397258276214088 /
# Test Accuracy: 0.8398333333333333
#
# ---
#
# **For Is_Thinker target:**
#
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}
#
# Train Accuracy: 0.8705806370966062 /
# Test Accuracy: 0.8255833333333333
#
# ---
#
# **For Is_Judger target:**
#
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Train Accuracy: 0.871497322860893 /
# Test Accuracy: 0.8269166666666666
#
#
# ---
#
# **For Is_Judger target:**
#
# Best Parameters: {'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Train Accuracy: 0.871497322860893 /
# Test Accuracy: 0.8269166666666666
#
#
#
# The model shows a little overfitting , but it has better results than the logistic Regression

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### **Random Forest**

# %%
models = {}
for trait in y_train.columns:
    rf_classifier = RandomForestClassifier(random_state=42)
    rf_classifier.fit(x_train, y_train[trait])
    models[trait] = rf_classifier


for trait, model in models.items():

    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)
   
    y_pred = model.predict(x_test)
    print(f"Classification Report for {trait}:\n")
    print(classification_report(y_test[trait], y_pred))
    print(f"Confusion Matrix for {trait}:\n")
    print(confusion_matrix(y_test[trait], y_pred))
    print("Train Accuracy:", accuracy_score(y_train[trait], y_pred_train))
    print("Test Accuracy:", accuracy_score(y_test[trait], y_pred_test))
    print("========================================================================\n")
# Out:
# Classification Report for Is_Extrovert:
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      5930
#            1       0.97      0.97      0.97      6070
#
#     accuracy                           0.97     12000
#    macro avg       0.97      0.97      0.97     12000
# weighted avg       0.97      0.97      0.97     12000
#
# Confusion Matrix for Is_Extrovert:
#
# [[5762  168]
#  [ 192 5878]]
# Train Accuracy: 1.0
# Test Accuracy: 0.97
# ========================================================================
#
# Classification Report for Is_Sensor:
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      5965
#            1       0.98      0.97      0.97      6035
#
#     accuracy                           0.97     12000
#    macro avg       0.97      0.97      0.97     12000
# weighted avg       0.97      0.97      0.97     12000
#
# Confusion Matrix for Is_Sensor:
#
# [[5851  114]
#  [ 199 5836]]
# Train Accuracy: 1.0
# Test Accuracy: 0.9739166666666667
# ========================================================================
#
# Classification Report for Is_Thinker:
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      6094
#            1       0.97      0.97      0.97      5906
#
#     accuracy                           0.97     12000
#    macro avg       0.97      0.97      0.97     12000
# weighted avg       0.97      0.97      0.97     12000
#
# Confusion Matrix for Is_Thinker:
#
# [[5904  190]
#  [ 188 5718]]
# Train Accuracy: 1.0
# Test Accuracy: 0.9685
# ========================================================================
#
# Classification Report for Is_Judger:
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      6047
#            1       0.97      0.96      0.97      5953
#
#     accuracy                           0.97     12000
#    macro avg       0.97      0.97      0.97     12000
# weighted avg       0.97      0.97      0.97     12000
#
# Confusion Matrix for Is_Judger:
#
# [[5861  186]
#  [ 217 5736]]
# Train Accuracy: 1.0
# Test Accuracy: 0.9664166666666667
# ========================================================================

# %% [markdown]
# ### **Random Forest Insights**:
#
#
# **For Is_Extrovert target:**
#
# Train Accuracy: 1.0 /
# Test Accuracy: 0.9691666666666666
#
# ---
#
# **For Is_Sensor target:**
#
# Train Accuracy: 1.0 /
# Test Accuracy: 0.97225
#
# ---
#
# **For Is_Thinker target:**
#
# Train Accuracy: 1.0 /
# Test Accuracy: 0.96358333
#
# ---
#
# **For Is_Judger target:**
#
# Train Accuracy: 1.0 /
# Test Accuracy: 0.9663
#
# This model shows good results in both train and test accuracy , but there's a little bit overfitting

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### **SVM**

# %%
models = {}
for trait in y_train.columns:
    svm_classifier = SVC(random_state=42)
    svm_classifier.fit(x_train, y_train[trait])
    models[trait] = svm_classifier
    
for trait, model in models.items():

    y_pred_train = model.predict(x_train)
    y_pred_test = model.predict(x_test)
   
    y_pred = model.predict(x_test)
    print(f"Classification Report for {trait}:\n")
    print(classification_report(y_test[trait], y_pred))
    print(f"Confusion Matrix for {trait}:\n")
    print(confusion_matrix(y_test[trait], y_pred))
    print("Train Accuracy:", accuracy_score(y_train[trait], y_pred_train))
    print("Test Accuracy:", accuracy_score(y_test[trait], y_pred_test))
    print("========================================================================\n")
# Out:
# Classification Report for Is_Extrovert:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5930
#            1       0.99      0.99      0.99      6070
#
#     accuracy                           0.99     12000
#    macro avg       0.99      0.99      0.99     12000
# weighted avg       0.99      0.99      0.99     12000
#
# Confusion Matrix for Is_Extrovert:
#
# [[5881   49]
#  [  47 6023]]
# Train Accuracy: 0.9941457113689869
# Test Accuracy: 0.992
# ========================================================================
#
# Classification Report for Is_Sensor:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5965
#            1       0.99      0.99      0.99      6035
#
#     accuracy                           0.99     12000
#    macro avg       0.99      0.99      0.99     12000
# weighted avg       0.99      0.99      0.99     12000
#
# Confusion Matrix for Is_Sensor:
#
# [[5925   40]
#  [  46 5989]]
# Train Accuracy: 0.9940832100668764
# Test Accuracy: 0.9928333333333333
# ========================================================================
#
# Classification Report for Is_Thinker:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6094
#            1       0.99      0.99      0.99      5906
#
#     accuracy                           0.99     12000
#    macro avg       0.99      0.99      0.99     12000
# weighted avg       0.99      0.99      0.99     12000
#
# Confusion Matrix for Is_Thinker:
#
# [[6028   66]
#  [  39 5867]]
# Train Accuracy: 0.9934790308131419
# Test Accuracy: 0.99125
# ========================================================================
#
# Classification Report for Is_Judger:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      6047
#            1       0.99      0.99      0.99      5953
#
#     accuracy                           0.99     12000
#    macro avg       0.99      0.99      0.99     12000
# weighted avg       0.99      0.99      0.99     12000
#
# Confusion Matrix for Is_Judger:
#
# [[5996   51]
#  [  54 5899]]
# Train Accuracy: 0.9933123606741807
# Test Accuracy: 0.99125
# ========================================================================

# %% [markdown]
# ### **SVM Insights:**
#
# **For Is_Extrovert target:**
#
# Train Accuracy: 0.9939 /
# Test Accuracy: 0.9916
#
# ---
#
# **For Is_Sensor target:**
#
# Train Accuracy: 0.9939 /
# Test Accuracy: 0.9916
#
# ---
#
# **For Is_Thinker target:**
#
# Train Accuracy: 0.9930 /
# Test Accuracy: 0.9904
#
# ---
#
# **For Is_Judger target:**
#
# Train Accuracy: 0.9931 /
# Test Accuracy: 0.99125
#
# -------
#
# **This model shows a perfect results in both training and test accuracy , showing no overfitting nor underfitting**

# %% [markdown]
# ---
# ---
#
# ### **Model Insights Summary**
#
# * **Logistic Regression:**
# Showed stable performance with no overfitting, but accuracy was relatively lower than other models.
#
# * **Decision Tree:**
# Achieved better accuracy than Logistic Regression, with slight overfitting.
#
# * **Random Forest:**
# Gave very high accuracy, but perfect training score indicates some overfitting.
#
# * **SVM:**
# Achieved the best performance with very high and consistent train/test accuracy, showing excellent generalization.
#
#
# #### **Final Choice**
#
# The **SVM model** was selected as the final model because it achieved the highest accuracy with no overfitting, making it the most reliable for this task.
